# %%
import numpy as np

def mostrar_sistema_matricial(a, b, c, d):
    A = np.array([[a, b], [c, d]])
    print("Sistema de ecuaciones en formato matricial:")
    print("d/dt [ x ] = [ a  b ] [ x ]")
    print("      [ y ]   [ c  d ] [ y ]")
    print("Matriz de coeficientes:")
    print(A)
    print("\nSistema de ecuaciones diferenciales:")
    print(f"dx/dt = {a}x + {b}y")
    print(f"dy/dt = {c}x + {d}y")
    
    # Ecuación característica para valores propios
    print("\nEcuación característica para valores propios:")
    print("det(A - λI) = 0")
    print(f"| {a}-λ  {b} |")
    print(f"| {c}  {d}-λ | = 0")
    
    # Desarrollo de la ecuación característica
    print("\nDesarrollo de la ecuación característica:")
    print(f"({a}-λ)({d}-λ) - ({b} * {c}) = 0")
    print(f"{a*d} - {a}λ - {d}λ + λ² - {b*c} = 0")
    print(f"λ² - ({a+d})λ + ({a*d - b*c}) = 0")
    print(f"Ecuación cuadrática: λ² - τλ + Δ = 0, donde")
    print(f"τ = {a+d} (traza de A)")
    print(f"Δ = {a*d - b*c} (determinante de A)")
    
    # Cálculo del discriminante
    discriminante = (a + d)**2 - 4 * (a*d - b*c)
    if abs(discriminante) < 1e-20:  # Condicional para valores muy pequeños
        discriminante = 0
    print("\nDiscriminante de la ecuación cuadrática:")
    print(f"Δ' = τ² - 4Δ")
    print(f"Δ' = ({a+d})² - 4({a*d - b*c})")
    print(f"Δ' = {discriminante}")
    
    # Cálculo de los valores propios
    if discriminante >= 0:
        lambda1 = ((a + d) + np.sqrt(discriminante)) / 2
        lambda2 = ((a + d) - np.sqrt(discriminante)) / 2
    else:
        lambda1 = complex((a + d) / 2, np.sqrt(-discriminante) / 2)
        lambda2 = complex((a + d) / 2, -np.sqrt(-discriminante) / 2)
    
    print("\nValores propios de A:")
    print(f"λ₁ = {lambda1}")
    print(f"λ₂ = {lambda2}")

# Definimos la matriz de coeficientes
a, b, c, d = 1, 2, 3, 4
mostrar_sistema_matricial(a, b, c, d)
# Out:
# Sistema de ecuaciones en formato matricial:
# d/dt [ x ] = [ a  b ] [ x ]
#       [ y ]   [ c  d ] [ y ]
# Matriz de coeficientes:
# [[1 2]
#  [3 4]]
#
# Sistema de ecuaciones diferenciales:
# dx/dt = 1x + 2y
# dy/dt = 3x + 4y
#
# Ecuación característica para valores propios:
# det(A - λI) = 0
# | 1-λ  2 |
# | 3  4-λ | = 0
#
# Desarrollo de la ecuación característica:
# (1-λ)(4-λ) - (2 * 3) = 0
# 4 - 1λ - 4λ + λ² - 6 = 0
# λ² - (5)λ + (-2) = 0
# Ecuación cuadrática: λ² - τλ + Δ = 0, donde
# τ = 5 (traza de A)
# Δ = -2 (determinante de A)
#
# Discriminante de la ecuación cuadrática:
# Δ' = τ² - 4Δ
# Δ' = (5)² - 4(-2)
# Δ' = 33
#
# Valores propios de A:
# λ₁ = 5.372281323269014
# λ₂ = -0.3722813232690143

# %%
import numpy as np

# Función para mostrar el sistema de ecuaciones y calcular los valores propios
def mostrar_sistema_matricial(a, b, c, d):
    A = np.array([[a, b], [c, d]])
    output_str = ""
    
    # Imprimir el sistema de ecuaciones en formato matricial
    output_str += "Sistema de ecuaciones en formato matricial:\n"
    output_str += "d/dt [ x ] = [ a  b ] [ x ]\n"
    output_str += "      [ y ]   [ c  d ] [ y ]\n"
    output_str += "Matriz de coeficientes:\n"
    output_str += f"{A}\n"
    output_str += "\nSistema de ecuaciones diferenciales:\n"
    output_str += f"dx/dt = {a}x + {b}y\n"
    output_str += f"dy/dt = {c}x + {d}y\n"
    
    # Ecuación característica para valores propios
    output_str += "\nEcuación característica para valores propios:\n"
    output_str += "det(A - λI) = 0\n"
    output_str += f"| {a}-λ  {b} |\n"
    output_str += f"| {c}  {d}-λ | = 0\n"
    
    # Desarrollo de la ecuación característica
    output_str += "\nDesarrollo de la ecuación característica:\n"
    output_str += f"({a}-λ)({d}-λ) - ({b} * {c}) = 0\n"
    output_str += f"{a*d} - {a}λ - {d}λ + λ² - {b*c} = 0\n"
    output_str += f"λ² - ({a+d})λ + ({a*d - b*c}) = 0\n"
    output_str += f"Ecuación cuadrática: λ² - τλ + Δ = 0, donde\n"
    output_str += f"τ = {a+d} (traza de A)\n"
    output_str += f"Δ = {a*d - b*c} (determinante de A)\n"
    
    # Cálculo del discriminante
    discriminante = (a + d)**2 - 4 * (a*d - b*c)
    if abs(discriminante) < 1e-20:  # Condicional para valores muy pequeños
        discriminante = 0
    output_str += "\nDiscriminante de la ecuación cuadrática:\n"
    output_str += f"Δ' = τ² - 4Δ\n"
    output_str += f"Δ' = ({a+d})² - 4({a*d - b*c})\n"
    output_str += f"Δ' = {discriminante}\n"
    
    # Cálculo de los valores propios
    if discriminante >= 0:
        lambda1 = ((a + d) + np.sqrt(discriminante)) / 2
        lambda2 = ((a + d) - np.sqrt(discriminante)) / 2
    else:
        lambda1 = complex((a + d) / 2, np.sqrt(-discriminante) / 2)
        lambda2 = complex((a + d) / 2, -np.sqrt(-discriminante) / 2)
    
    output_str += "\nValores propios de A:\n"
    output_str += f"λ₁ = {lambda1}\n"
    output_str += f"λ₂ = {lambda2}\n"
    
    print(output_str)

# Definimos los valores de a, b, c, d
a, b, c, d = 1, 2, 3, 4

# Mostrar el sistema con los valores definidos
mostrar_sistema_matricial(a, b, c, d)
# Out:
# Sistema de ecuaciones en formato matricial:
# d/dt [ x ] = [ a  b ] [ x ]
#       [ y ]   [ c  d ] [ y ]
# Matriz de coeficientes:
# [[1 2]
#  [3 4]]
#
# Sistema de ecuaciones diferenciales:
# dx/dt = 1x + 2y
# dy/dt = 3x + 4y
#
# Ecuación característica para valores propios:
# det(A - λI) = 0
# | 1-λ  2 |
# | 3  4-λ | = 0
#
# Desarrollo de la ecuación característica:
# (1-λ)(4-λ) - (2 * 3) = 0
# 4 - 1λ - 4λ + λ² - 6 = 0
# λ² - (5)λ + (-2) = 0
# Ecuación cuadrática: λ² - τλ + Δ = 0, donde
# τ = 5 (traza de A)
# Δ = -2 (determinante de A)
#
# Discriminante de la ecuación cuadrática:
# Δ' = τ² - 4Δ
# Δ' = (5)² - 4(-2)
# Δ' = 33
#
# Valores propios de A:
# λ₁ = 5.372281323269014
# λ₂ = -0.3722813232690143

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText

# Define the system of differential equations with parameters
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Function to plot the phase diagram with nullclines and print the matrix and equations
def plot_phase_diagram(a, b, c, d):
    # Create a grid of points with higher resolution
    x = np.linspace(-10, 10, 20)  # Increased number of points for smoother flow
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)

    # Compute the derivatives at each point
    DX, DY = system(X, Y, a, b, c, d)
    
    # Print the coefficient matrix
    coef_matrix = np.array([[a, b], [c, d]])
    print("Coefficient Matrix:")
    print(coef_matrix)
    
    # Print the system of differential equations
    print("System of Differential Equations:")
    print(f"dx/dt = {a}x + {b}y")
    print(f"dy/dt = {c}x + {d}y")
    
    # Plot the phase diagram
    plt.figure(figsize=(8, 6))
    plt.streamplot(X, Y, DX, DY, color='black')

    # Calculate and plot the nullclines
    nullcline_x = a * X + b * Y
    nullcline_y = c * X + d * Y

    # Contours where dx/dt = 0 (red) and dy/dt = 0 (blue)
    plt.contour(X, Y, nullcline_x, levels=[0], colors='red', linewidths=2)
    plt.contour(X, Y, nullcline_y, levels=[0], colors='blue', linewidths=2)
    
    # Display the equations on the plot
    eq_text = (f"dx/dt = {a}x + {b}y\n"
               f"dy/dt = {c}x + {d}y")
    plt.text(-9, 9, eq_text, fontsize=10, bbox=dict(facecolor='white', alpha=0.5))
    
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Phase Diagram with Nullclines')
    plt.grid()
    plt.show()

# Create interactive inputs
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText

# Define the system of differential equations with parameters
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Function to plot the phase diagram with nullclines and print the matrix and equations
def plot_phase_diagram(a, b, c, d):
    # Create a grid of points with higher resolution
    x = np.linspace(-10, 10, 20)  # Increased number of points for smoother flow
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)

    # Compute the derivatives at each point
    DX, DY = system(X, Y, a, b, c, d)
    
    # Print the coefficient matrix with title
    coef_matrix = np.array([[a, b], [c, d]])
    print("Matriz de coeficientes:")
    print(coef_matrix)
    
    # Print the system of differential equations
    print("Sistema de Ecuaciones Diferenciales:")
    print(f"dx/dt = {a}x + {b}y")
    print(f"dy/dt = {c}x + {d}y")
    
    # Plot the phase diagram
    plt.figure(figsize=(8, 6))
    plt.streamplot(X, Y, DX, DY, color='black')

    # Calculate and plot the nullclines
    nullcline_x = a * X + b * Y
    nullcline_y = c * X + d * Y

    # Contours where dx/dt = 0 (red) and dy/dt = 0 (blue)
    plt.contour(X, Y, nullcline_x, levels=[0], colors='red', linewidths=2)
    plt.contour(X, Y, nullcline_y, levels=[0], colors='blue', linewidths=2)
    
    # Display the equations on the plot
    eq_text = (f"dx/dt = {a}x + {b}y\n"
               f"dy/dt = {c}x + {d}y")
    plt.text(-9, 9, eq_text, fontsize=10, bbox=dict(facecolor='white', alpha=0.5))
    
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Phase Diagram with Nullclines')
    plt.grid()
    plt.show()

# Create interactive inputs
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText

# Define the system of differential equations with parameters
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Function to calculate eigenvalues and display the characteristic equation
def calculate_eigenvalues(a, b, c, d):
    # Coefficients for the characteristic equation
    trace = a + d  # a + d is the trace of the matrix
    determinant = a * d - b * c  # ad - bc is the determinant
    
    # Eigenvalue equation: lambda^2 - (trace)*lambda + determinant = 0
    print("Ecuación característica: λ^2 - (a + d)λ + (ad - bc) = 0")
    print(f"Determinante = {determinant}")
    print(f"Traza = {trace}")
    
    # Calculate the eigenvalues using the quadratic formula
    discriminant = trace**2 - 4 * determinant
    if discriminant >= 0:
        lambda_1 = (trace + np.sqrt(discriminant)) / 2
        lambda_2 = (trace - np.sqrt(discriminant)) / 2
        print(f"Valores propios: λ₁ = {lambda_1}, λ₂ = {lambda_2}")
    else:
        real_part = trace / 2
        imaginary_part = np.sqrt(-discriminant) / 2
        print(f"Valores propios complejos: λ₁ = {real_part} + {imaginary_part}i, λ₂ = {real_part} - {imaginary_part}i")

# Function to plot the phase diagram with nullclines, eigenvalues, and print the matrix and equations
def plot_phase_diagram(a, b, c, d):
    # Create a grid of points with higher resolution
    x = np.linspace(-10, 10, 20)  # Increased number of points for smoother flow
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)

    # Compute the derivatives at each point
    DX, DY = system(X, Y, a, b, c, d)
    
    # Print the coefficient matrix with title
    coef_matrix = np.array([[a, b], [c, d]])
    print("Matriz de coeficientes:")
    print(coef_matrix)
    
    # Print the system of differential equations
    print("Sistema de Ecuaciones Diferenciales:")
    print(f"dx/dt = {a}x + {b}y")
    print(f"dy/dt = {c}x + {d}y")
    
    # Calculate and display eigenvalues
    calculate_eigenvalues(a, b, c, d)
    
    # Plot the phase diagram
    plt.figure(figsize=(8, 6))
    plt.streamplot(X, Y, DX, DY, color='black')

    # Calculate and plot the nullclines
    nullcline_x = a * X + b * Y
    nullcline_y = c * X + d * Y

    # Contours where dx/dt = 0 (red) and dy/dt = 0 (blue)
    plt.contour(X, Y, nullcline_x, levels=[0], colors='red', linewidths=2)
    plt.contour(X, Y, nullcline_y, levels=[0], colors='blue', linewidths=2)
    
    # Display the equations on the plot
    eq_text = (f"dx/dt = {a}x + {b}y\n"
               f"dy/dt = {c}x + {d}y")
    plt.text(-9, 9, eq_text, fontsize=10, bbox=dict(facecolor='white', alpha=0.5))
    
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Phase Diagram with Nullclines')
    plt.grid()
    plt.show()

# Create interactive inputs
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText

# Define the system of differential equations with parameters
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Function to calculate eigenvalues and display the characteristic equation
def calculate_eigenvalues(a, b, c, d):
    # Coefficients for the characteristic equation
    trace = a + d  # a + d is the trace of the matrix
    determinant = a * d - b * c  # ad - bc is the determinant
    
    # Eigenvalue equation: det(A - λI) = 0
    print("Ecuación característica: det(A - λI) = 0")
    print(f"Donde A es la matriz de coeficientes: A = [[{a}, {b}], [{c}, {d}]]")
    print(f"La ecuación característica es: (a - λ)(d - λ) - bc = 0")
    print(f"Determinante = {determinant}")
    print(f"Traza = {trace}")
    
    # Calculate the eigenvalues using the quadratic formula
    discriminant = trace**2 - 4 * determinant
    if discriminant >= 0:
        lambda_1 = (trace + np.sqrt(discriminant)) / 2
        lambda_2 = (trace - np.sqrt(discriminant)) / 2
        print(f"Valores propios: λ₁ = {lambda_1}, λ₂ = {lambda_2}")
    else:
        real_part = trace / 2
        imaginary_part = np.sqrt(-discriminant) / 2
        print(f"Valores propios complejos: λ₁ = {real_part} + {imaginary_part}i, λ₂ = {real_part} - {imaginary_part}i")

# Function to plot the phase diagram with nullclines, eigenvalues, and print the matrix and equations
def plot_phase_diagram(a, b, c, d):
    # Create a grid of points with higher resolution
    x = np.linspace(-10, 10, 20)  # Increased number of points for smoother flow
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)

    # Compute the derivatives at each point
    DX, DY = system(X, Y, a, b, c, d)
    
    # Print the coefficient matrix with title
    coef_matrix = np.array([[a, b], [c, d]])
    print("Matriz de coeficientes:")
    print(coef_matrix)
    
    # Print the system of differential equations
    print("Sistema de Ecuaciones Diferenciales:")
    print(f"dx/dt = {a}x + {b}y")
    print(f"dy/dt = {c}x + {d}y")
    
    # Calculate and display eigenvalues
    calculate_eigenvalues(a, b, c, d)
    
    # Plot the phase diagram
    plt.figure(figsize=(8, 6))
    plt.streamplot(X, Y, DX, DY, color='black')

    # Calculate and plot the nullclines
    nullcline_x = a * X + b * Y
    nullcline_y = c * X + d * Y

    # Contours where dx/dt = 0 (red) and dy/dt = 0 (blue)
    plt.contour(X, Y, nullcline_x, levels=[0], colors='red', linewidths=2)
    plt.contour(X, Y, nullcline_y, levels=[0], colors='blue', linewidths=2)
    
    # Display the equations on the plot
    eq_text = (f"dx/dt = {a}x + {b}y\n"
               f"dy/dt = {c}x + {d}y")
    plt.text(-9, 9, eq_text, fontsize=10, bbox=dict(facecolor='white', alpha=0.5))
    
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Phase Diagram with Nullclines')
    plt.grid()
    plt.show()

# Create interactive inputs
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText

# Define the system of differential equations with parameters
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Function to calculate eigenvalues and display the characteristic equation
def calculate_eigenvalues(a, b, c, d):
    # Coefficients for the characteristic equation
    trace = a + d  # a + d is the trace of the matrix
    determinant = a * d - b * c  # ad - bc is the determinant
    
    # Eigenvalue equation: det(A - λI) = 0
    print("\nEcuación característica: λ^2 - (Traza)λ + (Determinante) = 0")
    print(f"Donde la traza = {trace} y el determinante = {determinant}")
    print(f"La ecuación característica es: λ^2 - {trace}λ + {determinant} = 0")
    
    # Calculate the eigenvalues using the quadratic formula
    discriminant = trace**2 - 4 * determinant
    if discriminant >= 0:
        lambda_1 = (trace + np.sqrt(discriminant)) / 2
        lambda_2 = (trace - np.sqrt(discriminant)) / 2
        print(f"\nValores propios: λ₁ = {lambda_1}, λ₂ = {lambda_2}")
    else:
        real_part = trace / 2
        imaginary_part = np.sqrt(-discriminant) / 2
        print(f"\nValores propios complejos: λ₁ = {real_part} + {imaginary_part}i, λ₂ = {real_part} - {imaginary_part}i")

# Function to plot the phase diagram with nullclines, eigenvalues, and print the matrix and equations
def plot_phase_diagram(a, b, c, d):
    # Create a grid of points with higher resolution
    x = np.linspace(-10, 10, 20)  # Increased number of points for smoother flow
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)

    # Compute the derivatives at each point
    DX, DY = system(X, Y, a, b, c, d)
    
    # Print the system of differential equations
    print("\nSistema de Ecuaciones Diferenciales:")
    print(f"dx/dt = {a}x + {b}y")
    print(f"dy/dt = {c}x + {d}y")
    
    # Calculate and display eigenvalues
    calculate_eigenvalues(a, b, c, d)
    
    # Plot the phase diagram
    plt.figure(figsize=(8, 6))
    plt.streamplot(X, Y, DX, DY, color='black')

    # Calculate and plot the nullclines
    nullcline_x = a * X + b * Y
    nullcline_y = c * X + d * Y

    # Contours where dx/dt = 0 (red) and dy/dt = 0 (blue)
    plt.contour(X, Y, nullcline_x, levels=[0], colors='red', linewidths=2)
    plt.contour(X, Y, nullcline_y, levels=[0], colors='blue', linewidths=2)
    
    # Display the equations on the plot
    eq_text = (f"dx/dt = {a}x + {b}y\n"
               f"dy/dt = {c}x + {d}y")
    plt.text(-9, 9, eq_text, fontsize=10, bbox=dict(facecolor='white', alpha=0.5))
    
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Phase Diagram with Nullclines')
    plt.grid()
    plt.show()

# Create interactive inputs
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText

# Define the system of differential equations with parameters
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Function to calculate eigenvalues and display the characteristic equation
def calculate_eigenvalues(a, b, c, d):
    # Coefficients for the characteristic equation
    tao = a + d  # a + d is the trace of the matrix
    delta = a * d - b * c  # ad - bc is the determinant
    
    # Ecuacion de valores propios: det(A - λI) = 0
    print("\nEcuación característica: λ^2 - (τ)λ + (Δ) = 0")
    print(f"Donde τ (tau) = {tao} y Δ (delta) = {delta}")
    print(f"La ecuación característica es: λ^2 - {tao}λ + {delta} = 0")
    
    # Formula para calcular los valores propios
    discriminant = tao**2 - 4 * delta
    if discriminant >= 0:
        lambda_1 = (tao + np.sqrt(discriminant)) / 2
        lambda_2 = (tao - np.sqrt(discriminant)) / 2
        print(f"\nValores propios: λ₁ = {lambda_1}, λ₂ = {lambda_2}")
    else:
        real_part = tao / 2
        imaginary_part = np.sqrt(-discriminant) / 2
        print(f"\nValores propios complejos: λ₁ = {real_part} + {imaginary_part}i, λ₂ = {real_part} - {imaginary_part}i")

# Function to plot the phase diagram with nullclines, eigenvalues, and print the matrix and equations
def plot_phase_diagram(a, b, c, d):
    # Create a grid of points with higher resolution
    x = np.linspace(-10, 10, 20)  # Increased number of points for smoother flow
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)

    # Compute the derivatives at each point
    DX, DY = system(X, Y, a, b, c, d)
    
    # Print the system of differential equations
    print("\nSistema de Ecuaciones Diferenciales:")
    print(f"dx/dt = {a}x + {b}y")
    print(f"dy/dt = {c}x + {d}y")
    
    # Calculate and display eigenvalues
    calculate_eigenvalues(a, b, c, d)
    
    # Plot the phase diagram
    plt.figure(figsize=(8, 6))
    plt.streamplot(X, Y, DX, DY, color='black')

    # Calculate and plot the nullclines
    nullcline_x = a * X + b * Y
    nullcline_y = c * X + d * Y

    # Contours where dx/dt = 0 (red) and dy/dt = 0 (blue)
    plt.contour(X, Y, nullcline_x, levels=[0], colors='red', linewidths=2)
    plt.contour(X, Y, nullcline_y, levels=[0], colors='blue', linewidths=2)
    
    # Display the equations on the plot
    eq_text = (f"dx/dt = {a}x + {b}y\n"
               f"dy/dt = {c}x + {d}y")
    plt.text(-9, 9, eq_text, fontsize=10, bbox=dict(facecolor='white', alpha=0.5))
    
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Phase Diagram with Nullclines')
    plt.grid()
    plt.show()

# Create interactive inputs
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText

# Define the system of differential equations with parameters
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Function to calculate eigenvalues and display the characteristic equation
def calculate_eigenvalues(a, b, c, d):
    # Coefficients for the characteristic equation
    tao = a + d  # Traza
    delta = a * d - b * c  # Determinante
    
    # Eigenvalue equation: det(A - λI) = 0
    print("\nEcuación característica: λ² - (τ)λ + (Δ) = 0")
    print(f"Donde τ (tau) = {tao:.4f} y Δ (delta) = {delta:.4f}")
    print(f"La ecuación característica es: λ² - {tao:.4f}λ + {delta:.4f} = 0")
    
    # Calculate the eigenvalues using the quadratic formula
    discriminant = tao**2 - 4 * delta
    if discriminant >= 0:
        lambda_1 = (tao + np.sqrt(discriminant)) / 2
        lambda_2 = (tao - np.sqrt(discriminant)) / 2
        print(f"\nValores propios: λ₁ = {lambda_1:.4f}, λ₂ = {lambda_2:.4f}")
    else:
        real_part = tao / 2
        imaginary_part = np.sqrt(-discriminant) / 2
        print(f"\nValores propios complejos: λ₁ = {real_part:.4f} + {imaginary_part:.4f}i, λ₂ = {real_part:.4f} - {imaginary_part:.4f}i")

# Function to plot the phase diagram with nullclines, eigenvalues, and print the matrix and equations
def plot_phase_diagram(a, b, c, d):
    # Create a grid of points with higher resolution
    x = np.linspace(-10, 10, 20)  # Increased number of points for smoother flow
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)

    # Compute the derivatives at each point
    DX, DY = system(X, Y, a, b, c, d)
    
    # Print the system of differential equations
    print("\nSistema de Ecuaciones Diferenciales:")
    print(f"dx/dt = {a}x + {b}y")
    print(f"dy/dt = {c}x + {d}y")
    
    # Calculate and display eigenvalues
    calculate_eigenvalues(a, b, c, d)
    
    # Plot the phase diagram
    plt.figure(figsize=(8, 6))
    plt.streamplot(X, Y, DX, DY, color='black')

    # Calculate and plot the nullclines
    nullcline_x = a * X + b * Y
    nullcline_y = c * X + d * Y

    # Contours where dx/dt = 0 (red) and dy/dt = 0 (blue)
    plt.contour(X, Y, nullcline_x, levels=[0], colors='red', linewidths=2)
    plt.contour(X, Y, nullcline_y, levels=[0], colors='blue', linewidths=2)
    
    # Display the equations on the plot
    eq_text = (f"dx/dt = {a}x + {b}y\n"
               f"dy/dt = {c}x + {d}y")
    plt.text(-9, 9, eq_text, fontsize=10, bbox=dict(facecolor='white', alpha=0.5))
    
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Phase Diagram with Nullclines')
    plt.grid()
    plt.show()

# Create interactive inputs
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText

# Define the system of differential equations
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Function to calculate eigenvalues and display the characteristic equation
def calculate_eigenvalues(a, b, c, d):
    tao = a + d  # Traza
    delta = a * d - b * c  # Determinante
    
    # Eigenvalue equation: det(A - λI) = 0
    print("\nEcuación característica: λ² - (τ)λ + (Δ) = 0")
    print(f"Donde τ (tau) = {tao:.4f} y Δ (delta) = {delta:.4f}")
    print(f"La ecuación característica es: λ² - {tao:.4f}λ + {delta:.4f} = 0")
    
    # Calculate eigenvalues
    discriminant = tao**2 - 4 * delta
    if discriminant >= 0:
        lambda_1 = (tao + np.sqrt(discriminant)) / 2
        lambda_2 = (tao - np.sqrt(discriminant)) / 2
        print(f"\nValores propios: λ₁ = {lambda_1:.4f}, λ₂ = {lambda_2:.4f}")
    else:
        real_part = tao / 2
        imaginary_part = np.sqrt(-discriminant) / 2
        print(f"\nValores propios complejos: λ₁ = {real_part:.4f} + {imaginary_part:.4f}i, λ₂ = {real_part:.4f} - {imaginary_part:.4f}i")

# Function to simulate and plot the system
def simulate_system(a, b, c, d, x0=1, y0=1, t_max=10, dt=0.1):
    t_values = np.arange(0, t_max, dt)
    x_values = [x0]
    y_values = [y0]

    # Euler method for solving ODEs
    for t in t_values[:-1]:
        dxdt, dydt = system(x_values[-1], y_values[-1], a, b, c, d)
        x_values.append(x_values[-1] + dxdt * dt)
        y_values.append(y_values[-1] + dydt * dt)

    return t_values, x_values, y_values

# Function to plot everything
def plot_phase_diagram(a, b, c, d):
    # Create a grid of points
    x = np.linspace(-10, 10, 20)
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)

    # Compute the derivatives at each point
    DX, DY = system(X, Y, a, b, c, d)
    
    # Print the system of differential equations
    print("\nSistema de Ecuaciones Diferenciales:")
    print(f"dx/dt = {a}x + {b}y")
    print(f"dy/dt = {c}x + {d}y")
    
    # Calculate and display eigenvalues
    calculate_eigenvalues(a, b, c, d)

    # Solve the system over time
    t_values, x_values, y_values = simulate_system(a, b, c, d)
    
    # Create figure and subplots
    fig, axs = plt.subplots(3, 1, figsize=(8, 12))
    
    # Plot phase diagram
    axs[0].streamplot(X, Y, DX, DY, color='black')
    axs[0].set_xlabel('x')
    axs[0].set_ylabel('y')
    axs[0].set_title('Diagrama de Fases')

    # dx/dt vs. t
    dx_values = [system(x, y, a, b, c, d)[0] for x, y in zip(x_values, y_values)]
    axs[1].plot(t_values, dx_values, 'r', label='dx/dt')
    axs[1].set_xlabel('t')
    axs[1].set_ylabel('dx/dt')
    axs[1].set_title('dx/dt vs. t')
    axs[1].legend()
    axs[1].grid()

    # dy/dt vs. t
    dy_values = [system(x, y, a, b, c, d)[1] for x, y in zip(x_values, y_values)]
    axs[2].plot(t_values, dy_values, 'b', label='dy/dt')
    axs[2].set_xlabel('t')
    axs[2].set_ylabel('dy/dt')
    axs[2].set_title('dy/dt vs. t')
    axs[2].legend()
    axs[2].grid()

    # Show plots
    plt.tight_layout()
    plt.show()

# Create interactive inputs
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText

# Define the system of differential equations
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Function to calculate eigenvalues and display the characteristic equation
def calculate_eigenvalues(a, b, c, d):
    tao = a + d  # Traza
    delta = a * d - b * c  # Determinante
    
    print("\nEcuación característica: λ² - (τ)λ + (Δ) = 0")
    print(f"Donde τ (tau) = {tao:.4f} y Δ (delta) = {delta:.4f}")
    print(f"La ecuación característica es: λ² - {tao:.4f}λ + {delta:.4f} = 0")
    
    discriminant = tao**2 - 4 * delta
    if discriminant >= 0:
        lambda_1 = (tao + np.sqrt(discriminant)) / 2
        lambda_2 = (tao - np.sqrt(discriminant)) / 2
        print(f"\nValores propios: λ₁ = {lambda_1:.4f}, λ₂ = {lambda_2:.4f}")
    else:
        real_part = tao / 2
        imaginary_part = np.sqrt(-discriminant) / 2
        print(f"\nValores propios complejos: λ₁ = {real_part:.4f} + {imaginary_part:.4f}i, λ₂ = {real_part:.4f} - {imaginary_part:.4f}i")

# Function to simulate the system using Euler's method
def simulate_system(a, b, c, d, x0, y0, t_max=10, dt=0.1):
    t_values = np.arange(0, t_max, dt)
    x_values = [x0]
    y_values = [y0]

    for _ in t_values[:-1]:
        dxdt, dydt = system(x_values[-1], y_values[-1], a, b, c, d)
        x_values.append(x_values[-1] + dxdt * dt)
        y_values.append(y_values[-1] + dydt * dt)

    return t_values, x_values, y_values

# Function to plot the phase diagram and time evolution
def plot_phase_diagram(a, b, c, d, x0, y0):
    x = np.linspace(-10, 10, 20)
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)

    DX, DY = system(X, Y, a, b, c, d)
    
    print("\nSistema de Ecuaciones Diferenciales:")
    print(f"dx/dt = {a}x + {b}y")
    print(f"dy/dt = {c}x + {d}y")
    
    calculate_eigenvalues(a, b, c, d)

    t_values, x_values, y_values = simulate_system(a, b, c, d, x0, y0)
    
    fig, axs = plt.subplots(3, 1, figsize=(8, 12))
    
    # Phase Diagram
    axs[0].streamplot(X, Y, DX, DY, color='black')
    axs[0].plot(x0, y0, 'ro', markersize=8, label="Condición inicial")
    axs[0].set_xlabel('x')
    axs[0].set_ylabel('y')
    axs[0].set_title('Diagrama de Fases')
    axs[0].legend()

    # dx/dt vs. t
    dx_values = [system(x, y, a, b, c, d)[0] for x, y in zip(x_values, y_values)]
    axs[1].plot(t_values, dx_values, 'r', label='dx/dt')
    axs[1].set_xlabel('t')
    axs[1].set_ylabel('dx/dt')
    axs[1].set_title('dx/dt vs. t')
    axs[1].legend()
    axs[1].grid()

    # dy/dt vs. t
    dy_values = [system(x, y, a, b, c, d)[1] for x, y in zip(x_values, y_values)]
    axs[2].plot(t_values, dy_values, 'b', label='dy/dt')
    axs[2].set_xlabel('t')
    axs[2].set_ylabel('dy/dt')
    axs[2].set_title('dy/dt vs. t')
    axs[2].legend()
    axs[2].grid()

    plt.tight_layout()
    plt.show()

# Create interactive inputs
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')
x0_input = FloatText(value=1.0, description='x₀:')
y0_input = FloatText(value=1.0, description='y₀:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input, x0=x0_input, y0=y0_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d, x0, y0)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText

# Define the system of differential equations
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Function to calculate eigenvalues and eigenvectors
def calculate_eigenvalues_and_vectors(a, b, c, d):
    # Matriz de coeficientes
    A = np.array([[a, b], [c, d]])

    # Cálculo de valores propios y vectores propios
    eigenvalues, eigenvectors = np.linalg.eig(A)
    
    tao = a + d  # Traza
    delta = a * d - b * c  # Determinante
    
    print("\nEcuación característica: λ² - (τ)λ + (Δ) = 0")
    print(f"Donde τ (tau) = {tao:.4f} y Δ (delta) = {delta:.4f}")
    print(f"La ecuación característica es: λ² - {tao:.4f}λ + {delta:.4f} = 0")
    
    print(f"\nValores propios: λ₁ = {eigenvalues[0]:.4f}, λ₂ = {eigenvalues[1]:.4f}")
    
    print(f"\nVectores propios (columnas):")
    print(eigenvectors)

    return eigenvalues, eigenvectors

# Function to simulate the system using Euler's method
def simulate_system(a, b, c, d, x0, y0, t_max=10, dt=0.1):
    t_values = np.arange(0, t_max, dt)
    x_values = [x0]
    y_values = [y0]

    for _ in t_values[:-1]:
        dxdt, dydt = system(x_values[-1], y_values[-1], a, b, c, d)
        x_values.append(x_values[-1] + dxdt * dt)
        y_values.append(y_values[-1] + dydt * dt)

    return t_values, x_values, y_values

# Function to plot the phase diagram and eigenvectors
def plot_phase_diagram(a, b, c, d, x0, y0):
    x = np.linspace(-10, 10, 20)
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)

    DX, DY = system(X, Y, a, b, c, d)
    
    print("\nSistema de Ecuaciones Diferenciales:")
    print(f"dx/dt = {a}x + {b}y")
    print(f"dy/dt = {c}x + {d}y")
    
    eigenvalues, eigenvectors = calculate_eigenvalues_and_vectors(a, b, c, d)
    
    t_values, x_values, y_values = simulate_system(a, b, c, d, x0, y0)
    
    fig, axs = plt.subplots(3, 1, figsize=(8, 12))
    
    # Phase Diagram
    axs[0].streamplot(X, Y, DX, DY, color='black')
    axs[0].plot(x0, y0, 'ro', markersize=8, label="Condición inicial")
    
    # Graficar los vectores propios
    for i in range(2):
        vec = eigenvectors[:, i] * 5  # Escalar para visualizar mejor
        axs[0].arrow(0, 0, vec[0], vec[1], color='green', head_width=0.5, head_length=0.5, label=f"Vector propio {i+1}")

    axs[0].set_xlabel('x')
    axs[0].set_ylabel('y')
    axs[0].set_title('Diagrama de Fases con Vectores Propios')
    axs[0].legend()

    # dx/dt vs. t
    dx_values = [system(x, y, a, b, c, d)[0] for x, y in zip(x_values, y_values)]
    axs[1].plot(t_values, dx_values, 'r', label='dx/dt')
    axs[1].set_xlabel('t')
    axs[1].set_ylabel('dx/dt')
    axs[1].set_title('dx/dt vs. t')
    axs[1].legend()
    axs[1].grid()

    # dy/dt vs. t
    dy_values = [system(x, y, a, b, c, d)[1] for x, y in zip(x_values, y_values)]
    axs[2].plot(t_values, dy_values, 'b', label='dy/dt')
    axs[2].set_xlabel('t')
    axs[2].set_ylabel('dy/dt')
    axs[2].set_title('dy/dt vs. t')
    axs[2].legend()
    axs[2].grid()

    plt.tight_layout()
    plt.show()

# Create interactive inputs
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')
x0_input = FloatText(value=1.0, description='x₀:')
y0_input = FloatText(value=1.0, description='y₀:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input, x0=x0_input, y0=y0_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d, x0, y0)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText

# Definir el sistema de ecuaciones diferenciales
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Función para simular el sistema con el método de Euler
def simulate_system(a, b, c, d, x0, y0, t_max=10, dt=0.1):
    t_values = np.arange(0, t_max, dt)
    x_values = [x0]
    y_values = [y0]

    for _ in t_values[:-1]:
        dxdt, dydt = system(x_values[-1], y_values[-1], a, b, c, d)
        x_values.append(x_values[-1] + dxdt * dt)
        y_values.append(y_values[-1] + dydt * dt)

    return t_values, x_values, y_values

# Función para graficar el diagrama de fases con nullclines
def plot_phase_diagram(a, b, c, d, x0, y0):
    x = np.linspace(-10, 10, 20)
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)

    DX, DY = system(X, Y, a, b, c, d)
    
    print("\nSistema de Ecuaciones Diferenciales:")
    print(f"dx/dt = {a}x + {b}y")
    print(f"dy/dt = {c}x + {d}y")
    
    t_values, x_values, y_values = simulate_system(a, b, c, d, x0, y0)
    
    fig, axs = plt.subplots(3, 1, figsize=(8, 12))
    
    # Diagrama de fases
    axs[0].streamplot(X, Y, DX, DY, color='black')
    axs[0].plot(x0, y0, 'ro', markersize=8, label="Condición inicial")
    
    # Calcular y graficar las nullclines
    nullcline_x = a * X + b * Y  # dx/dt = 0
    nullcline_y = c * X + d * Y  # dy/dt = 0
    axs[0].contour(X, Y, nullcline_x, levels=[0], colors='red', linewidths=2, label='dx/dt = 0')
    axs[0].contour(X, Y, nullcline_y, levels=[0], colors='blue', linewidths=2, label='dy/dt = 0')

    axs[0].set_xlabel('x')
    axs[0].set_ylabel('y')
    axs[0].set_title('Diagrama de Fases con Nullclines')
    axs[0].legend()

    # dx/dt vs. t
    dx_values = [system(x, y, a, b, c, d)[0] for x, y in zip(x_values, y_values)]
    axs[1].plot(t_values, dx_values, 'r', label='dx/dt')
    axs[1].set_xlabel('t')
    axs[1].set_ylabel('dx/dt')
    axs[1].set_title('dx/dt vs. t')
    axs[1].legend()
    axs[1].grid()

    # dy/dt vs. t
    dy_values = [system(x, y, a, b, c, d)[1] for x, y in zip(x_values, y_values)]
    axs[2].plot(t_values, dy_values, 'b', label='dy/dt')
    axs[2].set_xlabel('t')
    axs[2].set_ylabel('dy/dt')
    axs[2].set_title('dy/dt vs. t')
    axs[2].legend()
    axs[2].grid()

    plt.tight_layout()
    plt.show()

# Crear inputs interactivos
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')
x0_input = FloatText(value=1.0, description='x₀:')
y0_input = FloatText(value=1.0, description='y₀:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input, x0=x0_input, y0=y0_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d, x0, y0)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText

# Definir el sistema de ecuaciones diferenciales
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Función para calcular valores propios y ecuación característica
def eigenvalues_and_characteristic_eq(a, b, c, d):
    A = np.array([[a, b], [c, d]])
    tau = np.trace(A)  # Traza (τ)
    delta = np.linalg.det(A)  # Determinante (Δ)

    # Ecuación característica: λ² - τλ + Δ = 0
    print("\nEcuación Característica:")
    print(f"λ² - {tau:.4f}λ + {delta:.4f} = 0")

    # Valores propios
    eigenvalues = np.linalg.eigvals(A)
    eigenvalues = np.round(eigenvalues, 4)  # Redondear a 4 decimales
    print(f"Valores propios: λ₁ = {eigenvalues[0]}, λ₂ = {eigenvalues[1]}\n")

# Función para simular el sistema con el método de Euler
def simulate_system(a, b, c, d, x0, y0, t_max=10, dt=0.1):
    t_values = np.arange(0, t_max, dt)
    x_values = [x0]
    y_values = [y0]

    for _ in t_values[:-1]:
        dxdt, dydt = system(x_values[-1], y_values[-1], a, b, c, d)
        x_values.append(x_values[-1] + dxdt * dt)
        y_values.append(y_values[-1] + dydt * dt)

    return t_values, x_values, y_values

# Función para graficar el diagrama de fases con nullclines
def plot_phase_diagram(a, b, c, d, x0, y0):
    # Imprimir la matriz de coeficientes
    print("\nMatriz de Coeficientes:")
    A = np.array([[a, b], [c, d]])
    print(A)

    # Imprimir ecuación característica y valores propios
    eigenvalues_and_characteristic_eq(a, b, c, d)

    # Crear la malla para el diagrama de fases
    x = np.linspace(-10, 10, 20)
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)
    DX, DY = system(X, Y, a, b, c, d)

    # Simular la trayectoria con las condiciones iniciales
    t_values, x_values, y_values = simulate_system(a, b, c, d, x0, y0)

    # Crear gráficos
    fig, axs = plt.subplots(3, 1, figsize=(8, 12))

    # --- Diagrama de fases ---
    axs[0].streamplot(X, Y, DX, DY, color='black')
    axs[0].plot(x0, y0, 'ro', markersize=8, label="Condición inicial")

    # Calcular y graficar las nullclines
    nullcline_x = a * X + b * Y  # dx/dt = 0
    nullcline_y = c * X + d * Y  # dy/dt = 0
    axs[0].contour(X, Y, nullcline_x, levels=[0], colors='red', linewidths=2)
    axs[0].contour(X, Y, nullcline_y, levels=[0], colors='blue', linewidths=2)

    axs[0].set_xlabel('x')
    axs[0].set_ylabel('y')
    axs[0].set_title('Diagrama de Fases con Nullclines')
    axs[0].legend()

    # --- dx/dt vs. t ---
    dx_values = [system(x, y, a, b, c, d)[0] for x, y in zip(x_values, y_values)]
    axs[1].plot(t_values, dx_values, 'r', label='dx/dt')
    axs[1].set_xlabel('t')
    axs[1].set_ylabel('dx/dt')
    axs[1].set_title('dx/dt vs. t')
    axs[1].legend()
    axs[1].grid()

    # --- dy/dt vs. t ---
    dy_values = [system(x, y, a, b, c, d)[1] for x, y in zip(x_values, y_values)]
    axs[2].plot(t_values, dy_values, 'b', label='dy/dt')
    axs[2].set_xlabel('t')
    axs[2].set_ylabel('dy/dt')
    axs[2].set_title('dy/dt vs. t')
    axs[2].legend()
    axs[2].grid()

    plt.tight_layout()
    plt.show()

# Crear inputs interactivos
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')
x0_input = FloatText(value=1.0, description='x₀:')
y0_input = FloatText(value=1.0, description='y₀:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input, x0=x0_input, y0=y0_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d, x0, y0)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText
from sympy import symbols, Eq, solve, exp

# Definir el sistema de ecuaciones diferenciales
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Resolver el sistema analíticamente
def analytical_solution(a, b, c, d, x0, y0):
    # Matriz A
    A = np.array([[a, b], [c, d]])

    # Valores propios y vectores propios
    eigenvalues, eigenvectors = np.linalg.eig(A)
    eigenvalues = np.round(eigenvalues, 4)  # Redondeo a 4 decimales

    # Condiciones iniciales
    C1, C2 = symbols('C1 C2')
    eq1 = Eq(C1 * eigenvectors[0, 0] + C2 * eigenvectors[0, 1], x0)
    eq2 = Eq(C1 * eigenvectors[1, 0] + C2 * eigenvectors[1, 1], y0)
    solution = solve((eq1, eq2), (C1, C2))

    # Expresión general de x(t) y y(t)
    t = symbols('t')
    x_t = solution[C1] * eigenvectors[0, 0] * exp(eigenvalues[0] * t) + solution[C2] * eigenvectors[0, 1] * exp(eigenvalues[1] * t)
    y_t = solution[C1] * eigenvectors[1, 0] * exp(eigenvalues[0] * t) + solution[C2] * eigenvectors[1, 1] * exp(eigenvalues[1] * t)

    print("\nSoluciones analíticas:")
    print(f"x(t) = {x_t}")
    print(f"y(t) = {y_t}\n")

# Simulación numérica del sistema
def simulate_system(a, b, c, d, x0, y0, t_max=10, dt=0.1):
    t_values = np.arange(0, t_max, dt)
    x_values = [x0]
    y_values = [y0]

    for _ in t_values[:-1]:
        dxdt, dydt = system(x_values[-1], y_values[-1], a, b, c, d)
        x_values.append(x_values[-1] + dxdt * dt)
        y_values.append(y_values[-1] + dydt * dt)

    return t_values, x_values, y_values

# Función para graficar el diagrama de fases y las nullclines
def plot_phase_diagram(a, b, c, d, x0, y0):
    # Imprimir la matriz de coeficientes
    print("\nMatriz de Coeficientes:")
    A = np.array([[a, b], [c, d]])
    print(A)

    # Ecuación característica
    tau = np.trace(A)  # Traza (τ)
    delta = np.linalg.det(A)  # Determinante (Δ)
    print("\nEcuación Característica:")
    print(f"λ² - {tau:.4f}λ + {delta:.4f} = 0")

    # Valores propios
    eigenvalues = np.linalg.eigvals(A)
    eigenvalues = np.round(eigenvalues, 4)
    print(f"Valores propios: λ₁ = {eigenvalues[0]}, λ₂ = {eigenvalues[1]}")

    # Soluciones analíticas
    analytical_solution(a, b, c, d, x0, y0)

    # Crear malla para diagrama de fases
    x = np.linspace(-10, 10, 20)
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)
    DX, DY = system(X, Y, a, b, c, d)

    # Simulación numérica
    t_values, x_values, y_values = simulate_system(a, b, c, d, x0, y0)

    # Crear gráficos
    fig, axs = plt.subplots(3, 1, figsize=(8, 12))

    # --- Diagrama de fases ---
    axs[0].streamplot(X, Y, DX, DY, color='black')
    axs[0].plot(x0, y0, 'ro', markersize=8, label="Condición inicial")

    # Nullclines
    nullcline_x = a * X + b * Y  # dx/dt = 0
    nullcline_y = c * X + d * Y  # dy/dt = 0
    axs[0].contour(X, Y, nullcline_x, levels=[0], colors='red', linewidths=2)
    axs[0].contour(X, Y, nullcline_y, levels=[0], colors='blue', linewidths=2)

    axs[0].set_xlabel('x')
    axs[0].set_ylabel('y')
    axs[0].set_title('Diagrama de Fases con Nullclines')
    axs[0].legend()

    # --- dx/dt vs. t ---
    dx_values = [system(x, y, a, b, c, d)[0] for x, y in zip(x_values, y_values)]
    axs[1].plot(t_values, dx_values, 'r', label='dx/dt')
    axs[1].set_xlabel('t')
    axs[1].set_ylabel('dx/dt')
    axs[1].set_title('dx/dt vs. t')
    axs[1].legend()
    axs[1].grid()

    # --- dy/dt vs. t ---
    dy_values = [system(x, y, a, b, c, d)[1] for x, y in zip(x_values, y_values)]
    axs[2].plot(t_values, dy_values, 'b', label='dy/dt')
    axs[2].set_xlabel('t')
    axs[2].set_ylabel('dy/dt')
    axs[2].set_title('dy/dt vs. t')
    axs[2].legend()
    axs[2].grid()

    plt.tight_layout()
    plt.show()

# Crear inputs interactivos
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')
x0_input = FloatText(value=1.0, description='x₀:')
y0_input = FloatText(value=1.0, description='y₀:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input, x0=x0_input, y0=y0_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d, x0, y0)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact_manual, FloatText
from sympy import symbols, Eq, solve, exp, latex
from IPython.display import display, Math

# Definir el sistema de ecuaciones diferenciales
def system(x, y, a, b, c, d):
    dxdt = a * x + b * y
    dydt = c * x + d * y
    return dxdt, dydt

# Resolver el sistema analíticamente
def analytical_solution(a, b, c, d, x0, y0):
    # Matriz A
    A = np.array([[a, b], [c, d]])

    # Valores propios y vectores propios
    eigenvalues, eigenvectors = np.linalg.eig(A)
    eigenvalues = np.round(eigenvalues, 4)  # Redondeo a 4 decimales

    # Condiciones iniciales
    C1, C2 = symbols('C1 C2')
    eq1 = Eq(C1 * eigenvectors[0, 0] + C2 * eigenvectors[0, 1], x0)
    eq2 = Eq(C1 * eigenvectors[1, 0] + C2 * eigenvectors[1, 1], y0)
    solution = solve((eq1, eq2), (C1, C2))
    C1_val = solution[C1]
    C2_val = solution[C2]

    # Expresión general de x(t) y y(t)
    t = symbols('t')
    x_t = C1_val * eigenvectors[0, 0] * exp(eigenvalues[0] * t) + C2_val * eigenvectors[0, 1] * exp(eigenvalues[1] * t)
    y_t = C1_val * eigenvectors[1, 0] * exp(eigenvalues[0] * t) + C2_val * eigenvectors[1, 1] * exp(eigenvalues[1] * t)

    # Mostrar soluciones analíticas en math_LaTeX
    print("\nSoluciones analíticas en Math_LaTeX:")
    display(Math(latex(x_t)))  # Esto asegura que la expresión se renderice correctamente en LaTeX
    display(Math(latex(y_t)))  # Igual para y(t)
    # También puedes imprimir el texto en formato LaTeX sin que se ejecute el código
    print(f"x(t) = {latex(x_t)}")
    print(f"y(t) = {latex(y_t)}")

# Simulación numérica del sistema
def simulate_system(a, b, c, d, x0, y0, t_max=10, dt=0.1):
    t_values = np.arange(0, t_max, dt)
    x_values = [x0]
    y_values = [y0]

    for _ in t_values[:-1]:
        dxdt, dydt = system(x_values[-1], y_values[-1], a, b, c, d)
        x_values.append(x_values[-1] + dxdt * dt)
        y_values.append(y_values[-1] + dydt * dt)

    return t_values, x_values, y_values

# Función para graficar el diagrama de fases y las nullclines
def plot_phase_diagram(a, b, c, d, x0, y0):
    # Imprimir la matriz de coeficientes
    print("\nMatriz de Coeficientes:")
    A = np.array([[a, b], [c, d]])
    print(A)

    # Ecuación característica
    tau = np.trace(A)  # Traza (τ)
    delta = np.linalg.det(A)  # Determinante (Δ)
    print("\nEcuación Característica:")
    print(f"λ² - {tau:.4f}λ + {delta:.4f} = 0")

    # Valores propios
    eigenvalues = np.linalg.eigvals(A)
    eigenvalues = np.round(eigenvalues, 4)
    print(f"Valores propios: λ₁ = {eigenvalues[0]}, λ₂ = {eigenvalues[1]}")

    # Soluciones analíticas
    analytical_solution(a, b, c, d, x0, y0)

    # Crear malla para diagrama de fases
    x = np.linspace(-10, 10, 20)
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)
    DX, DY = system(X, Y, a, b, c, d)

    # Simulación numérica
    t_values, x_values, y_values = simulate_system(a, b, c, d, x0, y0)

    # Crear gráficos
    fig, axs = plt.subplots(3, 1, figsize=(8, 12))

    # --- Diagrama de fases ---
    axs[0].streamplot(X, Y, DX, DY, color='black')
    axs[0].plot(x0, y0, 'ro', markersize=8, label="Condición inicial")

    # Nullclines
    nullcline_x = a * X + b * Y  # dx/dt = 0
    nullcline_y = c * X + d * Y  # dy/dt = 0
    axs[0].contour(X, Y, nullcline_x, levels=[0], colors='red', linewidths=2)
    axs[0].contour(X, Y, nullcline_y, levels=[0], colors='blue', linewidths=2)

    axs[0].set_xlabel('x')
    axs[0].set_ylabel('y')
    axs[0].set_title('Diagrama de Fases con Nullclines')
    axs[0].legend()

    # --- dx/dt vs. t ---
    dx_values = [system(x, y, a, b, c, d)[0] for x, y in zip(x_values, y_values)]
    axs[1].plot(t_values, dx_values, 'r', label='dx/dt')
    axs[1].set_xlabel('t')
    axs[1].set_ylabel('dx/dt')
    axs[1].set_title('dx/dt vs. t')
    axs[1].legend()
    axs[1].grid()

    # --- dy/dt vs. t ---
    dy_values = [system(x, y, a, b, c, d)[1] for x, y in zip(x_values, y_values)]
    axs[2].plot(t_values, dy_values, 'b', label='dy/dt')
    axs[2].set_xlabel('t')
    axs[2].set_ylabel('dy/dt')
    axs[2].set_title('dy/dt vs. t')
    axs[2].legend()
    axs[2].grid()

    plt.tight_layout()
    plt.show()

# Crear inputs interactivos
a_input = FloatText(value=1.0, description='a:')
b_input = FloatText(value=1.0, description='b:')
c_input = FloatText(value=-0.6, description='c:')
d_input = FloatText(value=1.0, description='d:')
x0_input = FloatText(value=1.0, description='x₀:')
y0_input = FloatText(value=1.0, description='y₀:')

interact_manual(plot_phase_diagram, a=a_input, b=b_input, c=c_input, d=d_input, x0=x0_input, y0=y0_input)
# Out:
# interactive(children=(FloatText(value=1.0, description='a:'), FloatText(value=1.0, description='b:'), FloatTex…
# <function __main__.plot_phase_diagram(a, b, c, d, x0, y0)>
